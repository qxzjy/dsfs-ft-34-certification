# %% [markdown]
# # Random Forest Classifier

# %%
# Data viz
import matplotlib.pyplot as plt

# Data manipulation
import pandas as pd

# Machine Learning
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, ConfusionMatrixDisplay, recall_score, RocCurveDisplay
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
data_train = pd.read_csv("../data/conversion_data_train.csv")
display(data_train.head())
# Out:
#    country  age new_user  source  total_pages_visited  converted
# 0    China   22      Yes  Direct                    2          0
# 1       UK   21      Yes     Ads                    3          0
# 2  Germany   20       No     Seo                   14          1
# 3       US   23      Yes     Seo                    3          0
# 4       US   28      Yes  Direct                    3          0

# %% [markdown]
# ## Train dataset

# %% [markdown]
# This model will be a Random Forest Classifier taking into account all columns as a feature. To compensate for the imbalance in the target distribution, we'll give greater weight to class 1.

# %% [markdown]
# #### Training and predictions

# %%
target = "converted"

X = data_train.drop(target, axis=1)
y = data_train[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
numerical_columns = X_train.select_dtypes(exclude=["object"]).columns
categorical_columns = X_train.select_dtypes(include="object").columns

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical_columns),
        ("cat", OneHotEncoder(drop="first"), categorical_columns)
    ])

X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
rfc = RandomForestClassifier(class_weight={0: 1, 1: 2})
rfc.fit(X_train, y_train)

param_grid = {
    "n_estimators": [200],
    "max_depth": [10, 15],
    "min_samples_leaf": [1, 5, 10],
    "class_weight": ["balanced", {0: 1, 1: 2}]
}

grid_search = GridSearchCV(rfc, param_grid, scoring="f1", cv=3)
grid_search.fit(X_train, y_train)

model = grid_search.best_estimator_

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %% [markdown]
# #### Performance assessment

# %%
scores = cross_val_score(model, X_train, y_train, cv=3)
print("The cross-validated mean score is : ", scores.mean())
print("The standard deviation is : ", scores.std())
# Out:
# The cross-validated mean score is :  0.985171129383653
# The standard deviation is :  0.0005088028458353953

# %%
print("f1-score on training set : ", f1_score(y_train, y_train_pred))
print("recall_score on training set : ", recall_score(y_train, y_train_pred))
print()
print("f1-score on test set : ", f1_score(y_test, y_test_pred))
print("recall_score on test set : ", recall_score(y_test, y_test_pred))
# Out:
# f1-score on training set :  0.7800307649279821
# recall_score on training set :  0.7595315904139434
#
# f1-score on test set :  0.7605712685522262
# recall_score on test set :  0.7396514161220044

# %%
_, ax = plt.subplots()
ax.set(title="Train Confusion Matrix")
ConfusionMatrixDisplay.from_estimator(model, X_train, y_train, ax=ax)
plt.show()

_, ax = plt.subplots()
ax.set(title="Test Confusion Matrix")
ConfusionMatrixDisplay.from_estimator(model, X_test, y_test, ax=ax)
plt.show()

# %%
_, ax = plt.subplots()
ax.set(title="Train ROC Curve")
RocCurveDisplay.from_estimator(model, X_train, y_train, ax=ax)
plt.show()

_, ax = plt.subplots()
ax.set(title="Test ROC Curve")
RocCurveDisplay.from_estimator(model, X_test, y_test, ax=ax)
plt.show()

# %% [markdown]
# The Random Forest model shows a slight improvement over logistic regression, particularly in the ability to identify the minority class.
#
# However, there may be a slight overlearning based on the discrepancy between training and test scores.

# %% [markdown]
# ## Test dataset

# %% [markdown]
# ### Predictions

# %%
data_test = pd.read_csv("../data/conversion_data_test.csv")

x_test = data_test
x_test = preprocessor.transform(x_test)

y_test = pd.read_csv("../data/conversion_data_test_labels.csv")
y_pred = model.predict(x_test)

print("f1-score on set without labels : ", f1_score(y_test, y_pred))
print("recall_score on set without labels : ", recall_score(y_test, y_pred))
# Out:
# f1-score on set without labels :  0.7583756345177665
# recall_score on set without labels :  0.7323529411764705

# %% [markdown]
# ### Performance assessment

# %%
scores_df = pd.DataFrame(columns = ["model", "f1", "recall"])
new_rows = [{"model": "rfc", "f1": f1_score(y_test, y_pred), "recall": recall_score(y_test, y_pred)}]
scores_df = pd.concat([scores_df, pd.DataFrame(new_rows)], ignore_index=True)
scores_df.to_csv("../data/scores.csv", mode="a", header=False, index=False)
# Out:
# /var/folders/yt/qrbwlc0x6fj2rs4chrxkrm_m0000gn/T/ipykernel_29884/1474283398.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   scores_df = pd.concat([scores_df, pd.DataFrame(new_rows)], ignore_index=True)
